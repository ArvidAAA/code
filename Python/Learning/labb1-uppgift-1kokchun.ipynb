# %%
#1:a
#Beräkna avståndet från origo till (x, y) = (0.5, 0.5)

#Tänker använda mig utav Pytagoras Sats.

#Math modulen för att använda mig utav roten ur.
import math

x = 0.5
y = 0.5

math.sqrt(x**2 + y**2)

# %%
#1:b
#Beräkna avståndet från origo till (x, y) = (1, 1)

###Samma tänk som föregående uppgift###

#Tänker använda mig utav Pytagoras Sats.

#Math modulen för att använda mig utav roten ur.
import math

x = 1
y = 1

math.sqrt(x**2 + y**2)

# %%
#1:c
#Beräkna avståndet från origo till (x, y) = (0.5, −0.5)

###Samma tänk som föregående uppgift###

#Tänker använda mig utav Pytagoras Sats.

#Math modulen för att använda mig utav roten ur.
import math

x = 0.5
y = -0.5

math.sqrt(x**2 + y**2)

# %%
#1:d

#Simulera många punkter slumpmässigt mellan -1 och 1 för x- och y-koordinater,
#genom att använda funktionen random.uniform(-1,1).



import random


#variabler som innehåller värden
x = -1
y = 1


#Gör så jag får 10 slumpmässiga tal
for s in range(10):
    koordinat1 = random.uniform(x, y)
    koordinat2 = random.uniform(x, y)
    print(f"{koordinat1}, {koordinat2}")
# Out:
# -0.11272154967185322, 0.047042341471709825
# -0.8951580726332142, 0.44772598854528955
# -0.41131037549317107, 0.736620329009541
# 0.08811822969828254, -0.604832990460648
# 0.9773669292601637, -0.5758776144080595
# 0.27328366910407964, -0.1954752055842106
# -0.4360031237135815, 0.10876865693386883
# 0.7677734170630544, 0.1985662201727021
# 0.6016252701765914, -0.5089746682864036
# -0.700293581096719, -0.5406343081256544

# %%
#1:e

#Räkna antalet punkter som hamnar inne i cirkeln och dividera med antalet simule-
#rade punkter.

# Om: x^2 + y^2 < radien^2 så är punkten i cirkeln

#Importerar nödvändiga moduler.
import random
import math


#variabler som innehåller värden
x = -1
y = 1
#Antal punkter jag simulerar
antal = 10

punktercirkel = 0

#Gör så jag får 10 slumpmässiga tal
for s in range(antal):
    koordinat1 = random.uniform(x, y)
    koordinat2 = random.uniform(x, y)
    print(f"{koordinat1}, {koordinat2}")
    print(" ")

    #Kollar så punkterna innanför cirkeln eftersom att radien är 1
    if math.sqrt(koordinat1**2 + koordinat2**2) < 1:
        punktercirkel += 1


#printar ut hur många punkter som hammnar inom cirkeln
print(f"{punktercirkel} punkter hammnar inom cirkeln")

#dividera med antalet simule-rade punkter.
print(f"{punktercirkel / antal} dividerat antal simulerade punkter med antal inom cirkeln")

# %%
#1:f

#######################################################################
# COPY PASTE PÅ KODEN I UPPGIFT 1:e men med resultat * 4              #
#######################################################################


#Räkna antalet punkter som hamnar inne i cirkeln och dividera med antalet simule-
#rade punkter.

# Om: x^2 + y^2 < radien^2 så är punkten i cirkeln

#Importerar nödvändiga moduler.
import random
import math


#variabler som innehåller värden
x = -1
y = 1
#Antal punkter jag simulerar
antal = 1000

#Definerat variabeln pågrund av att jag behöver den senare, slipper få massa errors i visual studio code.
punktercirkel = 0

#Gör så jag får 10 slumpmässiga tal
for s in range(antal):
    koordinat1 = random.uniform(x, y)
    koordinat2 = random.uniform(x, y)
    print(f"{koordinat1}, {koordinat2}")
    print(" ")

    #Kollar så punkterna innanför cirkeln eftersom att radien är 1
    if math.sqrt(koordinat1**2 + koordinat2**2) < 1:
        punktercirkel += 1


#printar ut hur många punkter som hammnar inom cirkeln
print(f"{punktercirkel} punkter hammnar inom cirkeln")

#dividera med antalet simule-rade punkter.
print(f"{punktercirkel / antal} dividerat antal simulerade punkter med antal inom cirkeln")


#Skapar varibalen total
total = (punktercirkel / antal)


######################################################################################

#Desto fler punkter jag simulerar med desto närmare kommer jag Pi (3.14)
#Om jag testar simulera 10000 punnkter kommer jag väldigt nära Pi
# Area cirkel/c = Pi * r^2 : 3.14 * 1^2
# Area kvadrat/kv = b * h : 2*2 = 4
# Andel = Ac / Akv Pi*r^2/4 
# Pi / 4

#Multiplicerar variablen total med 4 som uppgiften 1:e lyder.
print(f"{total * 4}")

# %%
#1:g

#Räkna antalet punkter som hamnar inne i cirkeln och dividera med antalet simule-
#rade punkter.

# Om: x^2 + y^2 < radien^2 så är punkten i cirkeln

#Importerar nödvändiga moduler.
import random
import math

#Behöver importer matplot för uppgiften
import matplotlib.pyplot as plt


#variabler som innehåller värden
x = -1
y = 1

#Titel och x y definerat på grafen
plt.suptitle('Punkter innanför och utanför Cirkeln')
plt.xlabel('X')
plt.ylabel('Y')


#Antal punkter jag simulerar
antal = 5000

#Definerat variabeln pågrund av att jag behöver den senare, slipper få massa errors i visual studio code.
punktercirkel = 0

#Gör så jag får 10 slumpmässiga tal
for s in range(antal):
    koordinat1 = random.uniform(x, y)
    koordinat2 = random.uniform(x, y)
   # print(f"{koordinat1}, {koordinat2}")
   # print(" ")

    #Kollar så punkterna innanför cirkeln eftersom att radien är 1
    if math.sqrt(koordinat1**2 + koordinat2**2) < 1:
        punktercirkel += 1
        #Ritar ut punkterna innanför cirkeln
        plt.plot(koordinat1,koordinat2,"*r")
    else:
        plt.plot(koordinat1,koordinat2,"*g")





#printar ut hur många punkter som hammnar inom cirkeln
print(f"{punktercirkel} punkter hammnar inom cirkeln")

#dividera med antalet simule-rade punkter.
print(f"{punktercirkel / antal} dividerat antal simulerade punkter med antal inom cirkeln")


#Man märker tydligt att desto fler punkter jag simulerar ju tydligare ser du att det börjar likna en cirkel.
#Eftersom jag har olika färger på punkterna är det mycket tydligt vilka som är utanför cirkeln.
# Out:
# 3907 punkter hammnar inom cirkeln
# 0.7814 dividerat antal simulerade punkter med antal inom cirkeln

# %%
# 1:h

#Räkna antalet punkter som hamnar inne i cirkeln och dividera med antalet simule-
#rade punkter.

# Om: x^2 + y^2 < radien^2 så är punkten i cirkeln

#Importerar nödvändiga moduler.
import random
import math

#Behöver importer matplot för uppgiften
import matplotlib.pyplot as plt


#variabler som innehåller värden
x = -1
y = 1

#Antal punkter jag simulerar
antal = 5000

#Definerat variabeln pågrund av att jag behöver den senare, slipper få massa errors i visual studio code.
punktercirkel = 0

#Gör så jag får 10 slumpmässiga tal
for s in range(antal):
    koordinat1 = random.uniform(x, y)
    koordinat2 = random.uniform(x, y)
   # print(f"{koordinat1}, {koordinat2}")
   # print(" ")

    #Kollar så punkterna innanför cirkeln eftersom att radien är 1
    if math.sqrt(koordinat1**2 + koordinat2**2) < 1:
        punktercirkel += 1
        #Ritar ut punkterna innanför cirkeln
        plt.plot(koordinat1,koordinat2,"*r")
    else:
        plt.plot(koordinat1,koordinat2,"*g")



#printar ut hur många punkter som hammnar inom cirkeln
print(f"{punktercirkel} punkter hammnar inom cirkeln")

#dividera med antalet simule-rade punkter.
print(f"{punktercirkel / antal} dividerat antal simulerade punkter med antal inom cirkeln")


#Man märker tydligt att desto fler punkter jag simulerar ju tydligare ser du att det börjar likna en cirkel.
#Eftersom jag har olika färger på punkterna är det mycket tydligt vilka som är utanför cirkeln.
